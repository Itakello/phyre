# %%
import phyre.loader

# %%
# Load all tasks
all_tasks = phyre.loader.load_compiled_task_dict()

# %%
all_tasks['00000:000']
# Out:
# Task(taskId='00000:000', scene=Scene(bodies=[Body(position=Vector(x=128.0, y=-2.5), bodyType=1, angle=0.0, shapes=[Shape(polygon=Polygon(vertices=[Vector(x=128.0, y=2.5), Vector(x=-128.0, y=2.5), Vector(x=-128.0, y=-2.5), Vector(x=128.0, y=-2.5)]), circle=None)], color=6, shapeType=0, diameter=256.0488234692751), Body(position=Vector(x=-2.5, y=128.0), bodyType=1, angle=0.0, shapes=[Shape(polygon=Polygon(vertices=[Vector(x=2.5, y=128.0), Vector(x=-2.5, y=128.0), Vector(x=-2.5, y=-128.0), Vector(x=2.5, y=-128.0)]), circle=None)], color=6, shapeType=0, diameter=256.0488234692751), Body(position=Vector(x=128.0, y=258.5), bodyType=1, angle=0.0, shapes=[Shape(polygon=Polygon(vertices=[Vector(x=128.0, y=2.5), Vector(x=-128.0, y=2.5), Vector(x=-128.0, y=-2.5), Vector(x=128.0, y=-2.5)]), circle=None)], color=6, shapeType=0, diameter=256.0488234692751), Body(position=Vector(x=258.5, y=128.0), bodyType=1, angle=0.0, shapes=[Shape(polygon=Polygon(vertices=[Vector(x=2.5, y=128.0), Vector(x=-2.5, 
# ...
